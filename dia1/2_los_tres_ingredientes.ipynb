# %% [markdown]
# <a href="https://colab.research.google.com/github/iniguezd/cartagenaD0aChatGPT/blob/main/dia1/2_los_tres_ingredientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Librerías

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.datasets import load_iris

# %%
# !pip install torchviz
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.3-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchviz) (2.10.0+cpu)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from torchviz) (0.21)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torchviz) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torchviz) (3.0.3)
# Downloading torchviz-0.0.3-py3-none-any.whl (5.7 kB)
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.3

# %%
from torchviz import make_dot

# %% [markdown]
# # Iris dataset

# %%
# En PyTorch, los datasets deben heredar de torch.utils.data.Dataset
class IrisDataset(Dataset):
    # Inicializamos el dataset cargando los datos
    def __init__(self):
        data = load_iris()
        self.X = torch.tensor(
            data.data, dtype=torch.float32
        )  # (150, 4)
        self.y = torch.tensor(
            data.target, dtype=torch.long
        )  # (150,)

    # PyTorch necesita saber el tamaño del dataset
    def __len__(self):
        return self.X.shape[0]

    # PyTorch necesita poder indexar el dataset
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
full_iris_dataset = IrisDataset()

# %%
# ejemplos de muestras
for i in [1, 50, 100]:
    x, y = full_iris_dataset[i]
    print(f"Muestra {i}: x = {x}, y = {y}")
# Out:
# Muestra 1: x = tensor([4.9000, 3.0000, 1.4000, 0.2000]), y = 0
# Muestra 50: x = tensor([7.0000, 3.2000, 4.7000, 1.4000]), y = 1
# Muestra 100: x = tensor([6.3000, 3.3000, 6.0000, 2.5000]), y = 2

# %%
len(full_iris_dataset)
# Out:
# 150

# %% [markdown]
# # Definición de la red

# %%
class IrisRed(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(4, 3)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        h = self.fc1(x)   # (B, 3)
        return h

# el softmax no se suele incluir en el modelo porque
# 1) la función de pérdida CrossEntropyLoss ya lo incluye
# 2) y porque en inferencia se suele usar argmax (selección de la clase con mayor puntuación)

# %% [markdown]
# # Grafo computacional

# %%
# Instanciamos el modelo y el loss
# En PyTorch, el loss y el modelo suelen ser instanciados por separado
model = IrisRed()
criterion = nn.CrossEntropyLoss()

# Input dummy (batch size = 5)
x = torch.randn(5, 4, requires_grad=False)

# Forward
y = model(x)
# Loss
target = torch.tensor([1, 0, 2, 1, 2])  # clase verdadera
loss = criterion(y, target)


# Crear grafo computacional
dot = make_dot(loss, params=dict(model.named_parameters()))

# Mostrar o guardar
dot

# %% [markdown]
# # Stochastic Gradient Descent, dividr en batches

# %%
# esta función devuelve un iterador sobre batches
dataloader = DataLoader(full_iris_dataset, batch_size=16, shuffle=True)
# por otro lado, la red se ha definido para procesar batches de datos

# %% [markdown]
# # Juntamos los tres ingredientes

# %%
# instanciar modelo, loss y optimizador
# si se dispone de GPU, mover el modelo a GPU
# elegimos CPU o GPU en función de lo que tengamos configurado
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# la red se inicializa a pesos aleatorios cada vez que se instancia
model = IrisRed().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2)

# %%
num_epochs = 100
# durante un número de epochs
for epoch in range(1, num_epochs + 1):
    # poner el modelo en modo entrenamiento
    model.train()
    # para llevar la cuenta del loss y poder irlo viendo
    running_loss = 0.0
    n_seen = 0

    for xB, yB in dataloader:
        xB, yB = xB.to(device), yB.to(device)
        optimizer.zero_grad()      # reset gradientes
        logits = model(xB)         # forward
        loss = criterion(logits, yB)
        loss.backward()            # backward
        optimizer.step()           # update
        running_loss += loss.item() * xB.size(0) # para llevar la cuenta del loss y poder irlo viendo
        n_seen += xB.size(0)           # para llevar la cuenta del loss

    epoch_loss = running_loss / n_seen # loss medio en la epoch
    print(f"Epoch {epoch:03d} | train_loss = {epoch_loss:.4f}") # reportamos el loss
# Out:
# Epoch 001 | train_loss = 1.5165
# Epoch 002 | train_loss = 1.1318
# Epoch 003 | train_loss = 1.0176
# Epoch 004 | train_loss = 0.9587
# Epoch 005 | train_loss = 0.9059
# Epoch 006 | train_loss = 0.8601
# Epoch 007 | train_loss = 0.8221
# Epoch 008 | train_loss = 0.7901
# Epoch 009 | train_loss = 0.7580
# Epoch 010 | train_loss = 0.7298
# Epoch 011 | train_loss = 0.7080
# Epoch 012 | train_loss = 0.6802
# Epoch 013 | train_loss = 0.6656
# Epoch 014 | train_loss = 0.6479
# Epoch 015 | train_loss = 0.6368
# Epoch 016 | train_loss = 0.6185
# Epoch 017 | train_loss = 0.6082
# Epoch 018 | train_loss = 0.5905
# Epoch 019 | train_loss = 0.5817
# Epoch 020 | train_loss = 0.5778
# Epoch 021 | train_loss = 0.5625
# Epoch 022 | train_loss = 0.5581
# Epoch 023 | train_loss = 0.5490
# Epoch 024 | train_loss = 0.5410
# Epoch 025 | train_loss = 0.5358
# Epoch 026 | train_loss = 0.5294
# Epoch 027 | train_loss = 0.5223
# Epoch 028 | train_loss = 0.5187
# Epoch 029 | train_loss = 0.5133
# Epoch 030 | train_loss = 0.5089
# Epoch 031 | train_loss = 0.5002
# Epoch 032 | train_loss = 0.4980
# Epoch 033 | train_loss = 0.4853
# Epoch 034 | train_loss = 0.4922
# Epoch 035 | train_loss = 0.4814
# Epoch 036 | train_loss = 0.4782
# Epoch 037 | train_loss = 0.4753
# Epoch 038 | train_loss = 0.4768
# Epoch 039 | train_loss = 0.4652
# Epoch 040 | train_loss = 0.4643
# Epoch 041 | train_loss = 0.4600
# Epoch 042 | train_loss = 0.4581
# Epoch 043 | train_loss = 0.4570
# Epoch 044 | train_loss = 0.4500
# Epoch 045 | train_loss = 0.4478
# Epoch 046 | train_loss = 0.4482
# Epoch 047 | train_loss = 0.4477
# Epoch 048 | train_loss = 0.4422
# Epoch 049 | train_loss = 0.4393
# Epoch 050 | train_loss = 0.4343
# Epoch 051 | train_loss = 0.4297
# Epoch 052 | train_loss = 0.4294
# Epoch 053 | train_loss = 0.4256
# Epoch 054 | train_loss = 0.4279
# Epoch 055 | train_loss = 0.4227
# Epoch 056 | train_loss = 0.4171
# Epoch 057 | train_loss = 0.4176
# Epoch 058 | train_loss = 0.4170
# Epoch 059 | train_loss = 0.4133
# Epoch 060 | train_loss = 0.4128
# Epoch 061 | train_loss = 0.4086
# Epoch 062 | train_loss = 0.4080
# Epoch 063 | train_loss = 0.4045
# Epoch 064 | train_loss = 0.4027
# Epoch 065 | train_loss = 0.3998
# Epoch 066 | train_loss = 0.4014
# Epoch 067 | train_loss = 0.4004
# Epoch 068 | train_loss = 0.3944
# Epoch 069 | train_loss = 0.3948
# Epoch 070 | train_loss = 0.3920
# Epoch 071 | train_loss = 0.3943
# Epoch 072 | train_loss = 0.3903
# Epoch 073 | train_loss = 0.3907
# Epoch 074 | train_loss = 0.3836
# Epoch 075 | train_loss = 0.3835
# Epoch 076 | train_loss = 0.3818
# Epoch 077 | train_loss = 0.3822
# Epoch 078 | train_loss = 0.3816
# Epoch 079 | train_loss = 0.3823
# Epoch 080 | train_loss = 0.3792
# Epoch 081 | train_loss = 0.3736
# Epoch 082 | train_loss = 0.3717
# Epoch 083 | train_loss = 0.3741
# Epoch 084 | train_loss = 0.3709
# Epoch 085 | train_loss = 0.3669
# Epoch 086 | train_loss = 0.3681
# Epoch 087 | train_loss = 0.3623
# Epoch 088 | train_loss = 0.3631
# Epoch 089 | train_loss = 0.3617
# Epoch 090 | train_loss = 0.3617
# Epoch 091 | train_loss = 0.3614
# Epoch 092 | train_loss = 0.3561
# Epoch 093 | train_loss = 0.3573
# Epoch 094 | train_loss = 0.3537
# Epoch 095 | train_loss = 0.3600
# Epoch 096 | train_loss = 0.3528
# Epoch 097 | train_loss = 0.3511
# Epoch 098 | train_loss = 0.3527
# Epoch 099 | train_loss = 0.3497
# Epoch 100 | train_loss = 0.3516

# %% [markdown]
# # Ejercicio
#
# Divide el dataset en train y test, y entrena el modelo durante 100 epochs. Evalúa el accuracy en el conjunto de test.
# - `torch.utils.data.random_split`
# - `torch.argmax` con el parámetro `dim` (indica la dimensión a reducir). `dim` es equivalente a `axis` en NumPy. Seguntamente tengáis que usar `dim=1` para reducir la dimensión de las clases.
#
# Recuerda poner el modelo en modo evaluación con `model.eval()` cuando evalúes en el conjunto de test.

# %% [markdown]
# ### accuracy = hits / número de tests

# %%
# Divide el dataset en train y test

train_dataset, test_dataset = torch.utils.data.random_split(
    full_iris_dataset,
    [75, 75]
)

# %%
for i in [1, 30, 74]:
    x, y = train_dataset[i]
    print(f"Muestra {i}: x = {x}, y = {y}")
# Out:
# Muestra 1: x = tensor([5.9000, 3.0000, 5.1000, 1.8000]), y = 2
# Muestra 30: x = tensor([5.4000, 3.4000, 1.5000, 0.4000]), y = 0
# Muestra 74: x = tensor([6.5000, 3.0000, 5.5000, 1.8000]), y = 2

# %%
# entrena el modelo durante 100 epochs.
num_epochs = 100
# durante un número de epochs
for epoch in range(1, num_epochs + 1):
    # poner el modelo en modo entrenamiento
    model.train()
    # para llevar la cuenta del loss y poder irlo viendo
    running_loss = 0.0
    n_seen = 0

    for xB, yB in dataloader:
        xB, yB = xB.to(device), yB.to(device)
        optimizer.zero_grad()      # reset gradientes
        logits = model(xB)         # forward
        loss = criterion(logits, yB)
        loss.backward()            # backward
        optimizer.step()           # update
        running_loss += loss.item() * xB.size(0) # para llevar la cuenta del loss y poder irlo viendo
        n_seen += xB.size(0)           # para llevar la cuenta del loss

    epoch_loss = running_loss / n_seen # loss medio en la epoch
    print(f"Epoch {epoch:03d} | train_loss = {epoch_loss:.4f}") # reportamos el loss
# Out:
# Epoch 001 | train_loss = 2.2722
# Epoch 002 | train_loss = 2.2722
# Epoch 003 | train_loss = 2.2722
# Epoch 004 | train_loss = 2.2722
# Epoch 005 | train_loss = 2.2722
# Epoch 006 | train_loss = 2.2722
# Epoch 007 | train_loss = 2.2722
# Epoch 008 | train_loss = 2.2722
# Epoch 009 | train_loss = 2.2722
# Epoch 010 | train_loss = 2.2722
# Epoch 011 | train_loss = 2.2722
# Epoch 012 | train_loss = 2.2722
# Epoch 013 | train_loss = 2.2722
# Epoch 014 | train_loss = 2.2722
# Epoch 015 | train_loss = 2.2722
# Epoch 016 | train_loss = 2.2722
# Epoch 017 | train_loss = 2.2722
# Epoch 018 | train_loss = 2.2722
# Epoch 019 | train_loss = 2.2722
# Epoch 020 | train_loss = 2.2722
# Epoch 021 | train_loss = 2.2722
# Epoch 022 | train_loss = 2.2722
# Epoch 023 | train_loss = 2.2722
# Epoch 024 | train_loss = 2.2722
# Epoch 025 | train_loss = 2.2722
# Epoch 026 | train_loss = 2.2722
# Epoch 027 | train_loss = 2.2722
# Epoch 028 | train_loss = 2.2722
# Epoch 029 | train_loss = 2.2722
# Epoch 030 | train_loss = 2.2722
# Epoch 031 | train_loss = 2.2722
# Epoch 032 | train_loss = 2.2722
# Epoch 033 | train_loss = 2.2722
# Epoch 034 | train_loss = 2.2722
# Epoch 035 | train_loss = 2.2722
# Epoch 036 | train_loss = 2.2722
# Epoch 037 | train_loss = 2.2722
# Epoch 038 | train_loss = 2.2722
# Epoch 039 | train_loss = 2.2722
# Epoch 040 | train_loss = 2.2722
# Epoch 041 | train_loss = 2.2722
# Epoch 042 | train_loss = 2.2722
# Epoch 043 | train_loss = 2.2722
# Epoch 044 | train_loss = 2.2722
# Epoch 045 | train_loss = 2.2722
# Epoch 046 | train_loss = 2.2722
# Epoch 047 | train_loss = 2.2722
# Epoch 048 | train_loss = 2.2722
# Epoch 049 | train_loss = 2.2722
# Epoch 050 | train_loss = 2.2722
# Epoch 051 | train_loss = 2.2722
# Epoch 052 | train_loss = 2.2722
# Epoch 053 | train_loss = 2.2722
# Epoch 054 | train_loss = 2.2722
# Epoch 055 | train_loss = 2.2722
# Epoch 056 | train_loss = 2.2722
# Epoch 057 | train_loss = 2.2722
# Epoch 058 | train_loss = 2.2722
# Epoch 059 | train_loss = 2.2722
# Epoch 060 | train_loss = 2.2722
# Epoch 061 | train_loss = 2.2722
# Epoch 062 | train_loss = 2.2722
# Epoch 063 | train_loss = 2.2722
# Epoch 064 | train_loss = 2.2722
# Epoch 065 | train_loss = 2.2722
# Epoch 066 | train_loss = 2.2722
# Epoch 067 | train_loss = 2.2722
# Epoch 068 | train_loss = 2.2722
# Epoch 069 | train_loss = 2.2722
# Epoch 070 | train_loss = 2.2722
# Epoch 071 | train_loss = 2.2722
# Epoch 072 | train_loss = 2.2722
# Epoch 073 | train_loss = 2.2722
# Epoch 074 | train_loss = 2.2722
# Epoch 075 | train_loss = 2.2722
# Epoch 076 | train_loss = 2.2722
# Epoch 077 | train_loss = 2.2722
# Epoch 078 | train_loss = 2.2722
# Epoch 079 | train_loss = 2.2722
# Epoch 080 | train_loss = 2.2722
# Epoch 081 | train_loss = 2.2722
# Epoch 082 | train_loss = 2.2722
# Epoch 083 | train_loss = 2.2722
# Epoch 084 | train_loss = 2.2722
# Epoch 085 | train_loss = 2.2722
# Epoch 086 | train_loss = 2.2722
# Epoch 087 | train_loss = 2.2722
# Epoch 088 | train_loss = 2.2722
# Epoch 089 | train_loss = 2.2722
# Epoch 090 | train_loss = 2.2722
# Epoch 091 | train_loss = 2.2722
# Epoch 092 | train_loss = 2.2722
# Epoch 093 | train_loss = 2.2722
# Epoch 094 | train_loss = 2.2722
# Epoch 095 | train_loss = 2.2722
# Epoch 096 | train_loss = 2.2722
# Epoch 097 | train_loss = 2.2722
# Epoch 098 | train_loss = 2.2722
# Epoch 099 | train_loss = 2.2722
# Epoch 100 | train_loss = 2.2722
